# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

#os.chdir('C:\\Users\Matthew...')
path = os.getcwd()
path
# Out:
# 'C:\\Users\\Matthew\\Documents\\CS4375'

# %%
WageDF = pd.read_csv('Wage.csv')
WageDF.head()
# Out:
#    year  age            maritl      race     education              region  \
# 0  2003   18  1. Never Married  2. Black    2. HS Grad  2. Middle Atlantic
# 1  2003   19  1. Never Married  1. White  1. < HS Grad  2. Middle Atlantic
# 2  2003   19  1. Never Married  1. White  1. < HS Grad  2. Middle Atlantic
# 3  2003   19  1. Never Married  2. Black  1. < HS Grad  2. Middle Atlantic
# 4  2003   19  1. Never Married  1. White    2. HS Grad  2. Middle Atlantic
#
#          jobclass          health health_ins   logwage       wage
# 0   1. Industrial  2. >=Very Good     1. Yes  4.255273  70.476020
# 1   1. Industrial  2. >=Very Good      2. No  3.301030  27.140579
# 2   1. Industrial       1. <=Good      2. No  4.000000  54.598150
# 3  2. Information  2. >=Very Good      2. No  4.176091  65.110854
# 4   1. Industrial  2. >=Very Good      2. No  3.949390  51.903696

# %%
WageDF['maritl'] = WageDF['maritl'].str.slice(0,1).astype(int) #replace columns with slices as num from front
WageDF['race'] = WageDF['race'].str.slice(0,1).astype(int)
WageDF['education'] = WageDF['education'].str.slice(0,1).astype(int)
WageDF['region'] = WageDF['region'].str.slice(0,1).astype(int)
WageDF['jobclass'] = WageDF['jobclass'].str.slice(0,1).astype(int)
WageDF['health'] = WageDF['health'].str.slice(0,1).astype(int)
WageDF['health_ins'] = WageDF['health_ins'].str.slice(0,1).astype(int)

# %%
WageDF.to_csv(path + '\\' + 'Wage_New.csv', index=False, sep=',', header=True)#recreate the csv with new columns

# %%
sns.displot(WageDF, x = 'age', kde=True) #graph the age spread

# %%
WageDF.head() #show the new columns
# Out:
#    year  age  maritl  race  education  region  jobclass  health  health_ins  \
# 0  2003   18       1     2          2       2         1       2           1
# 1  2003   19       1     1          1       2         1       2           2
# 2  2003   19       1     1          1       2         1       1           2
# 3  2003   19       1     2          1       2         2       2           2
# 4  2003   19       1     1          2       2         1       2           2
#
#     logwage       wage
# 0  4.255273  70.476020
# 1  3.301030  27.140579
# 2  4.000000  54.598150
# 3  4.176091  65.110854
# 4  3.949390  51.903696

# %%
sns.scatterplot(x='age', y='wage', data=WageDF) #show age and salary correlation
# Out:
# <AxesSubplot:xlabel='age', ylabel='wage'>

# %%
sns.scatterplot(x='year', y='wage', data=WageDF) #show the year and wage correlation
# Out:
# <AxesSubplot:xlabel='year', ylabel='wage'>

# %%
sns.boxplot(x='education', y='wage', data=WageDF)
# Out:
# <AxesSubplot:xlabel='education', ylabel='wage'>

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3,figsize=(15,8))
sns.scatterplot(x='age', y='wage', data=WageDF, ax=ax1) #show age and salary correlation
sns.scatterplot(x='year', y='wage', data=WageDF, ax=ax2) #show the year and wage correlation
sns.boxplot(x='education', y='wage', data=WageDF, ax=ax3)
ax2.set_ylabel("")
ax3.set_ylabel("")
ax3.set_xlabel("education")
# Out:
# Text(0.5, 0, 'education')
