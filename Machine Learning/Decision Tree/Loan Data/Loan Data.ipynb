# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix,classification_report,plot_confusion_matrix
from sklearn.tree import plot_tree
from sklearn.metrics import mean_absolute_error, mean_squared_error

#os.chdir('C:\\Users\Matthew...')
path = os.getcwd()

df = pd.read_csv('loan_data.csv')

# %%
#EDA (Exploratory Data Analysis)
#Show head, info, and describe
df.head()
# Out:
#    credit.policy             purpose  int.rate  installment  log.annual.inc  \
# 0              0  debt_consolidation    0.1836       630.39       11.877569
# 1              0         credit_card    0.1576       192.72       10.691945
# 2              0           all_other    0.1791       144.43       10.868568
# 3              0         educational    0.1759       107.85       10.759072
# 4              0  debt_consolidation    0.1797       361.38       11.289782
#
#      dti  fico  days.with.cr.line  revol.bal  revol.util  inq.last.6mths  \
# 0  29.96   667       13979.041670     212629        87.4               3
# 1  29.95   692        2790.000000      26313        58.5               9
# 2  29.90   662        3119.958333      15473        65.3               0
# 3  29.74   662        4500.000000       2663        20.3               0
# 4  29.72   672        8489.958333      25879        77.2               2
#
#    delinq.2yrs  pub.rec  not.fully.paid
# 0            0        0               1
# 1            0        2               0
# 2            1        0               0
# 3            1        0               0
# 4            3        0               0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9578 entries, 0 to 9577
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   credit.policy      9578 non-null   int64
#  1   purpose            9578 non-null   object
#  2   int.rate           9578 non-null   float64
#  3   installment        9578 non-null   float64
#  4   log.annual.inc     9578 non-null   float64
#  5   dti                9578 non-null   float64
#  6   fico               9578 non-null   int64
#  7   days.with.cr.line  9578 non-null   float64
#  8   revol.bal          9578 non-null   int64
#  9   revol.util         9578 non-null   float64
#  10  inq.last.6mths     9578 non-null   int64
#  11  delinq.2yrs        9578 non-null   int64
#  12  pub.rec            9578 non-null   int64
#  13  not.fully.paid     9578 non-null   int64
# dtypes: float64(6), int64(7), object(1)
# memory usage: 1.0+ MB

# %%
df.describe()
# Out:
#        credit.policy     int.rate  installment  log.annual.inc          dti  \
# count    9578.000000  9578.000000  9578.000000     9578.000000  9578.000000
# mean        0.804970     0.122640   319.089413       10.932117    12.606679
# std         0.396245     0.026847   207.071301        0.614813     6.883970
# min         0.000000     0.060000    15.670000        7.547502     0.000000
# 25%         1.000000     0.103900   163.770000       10.558414     7.212500
# 50%         1.000000     0.122100   268.950000       10.928884    12.665000
# 75%         1.000000     0.140700   432.762500       11.291293    17.950000
# max         1.000000     0.216400   940.140000       14.528354    29.960000
#
#               fico  days.with.cr.line     revol.bal   revol.util  \
# count  9578.000000        9578.000000  9.578000e+03  9578.000000
# mean    710.846314        4560.767197  1.691396e+04    46.799236
# std      37.970537        2496.930377  3.375619e+04    29.014417
# min     612.000000         178.958333  0.000000e+00     0.000000
# 25%     682.000000        2820.000000  3.187000e+03    22.600000
# 50%     707.000000        4139.958333  8.596000e+03    46.300000
# 75%     737.000000        5730.000000  1.824950e+04    70.900000
# max     827.000000       17639.958330  1.207359e+06   119.000000
#
#        inq.last.6mths  delinq.2yrs      pub.rec  not.fully.paid
# count     9578.000000  9578.000000  9578.000000     9578.000000
# mean         1.577469     0.163708     0.062122        0.160054
# std          2.200245     0.546215     0.262126        0.366676
# min          0.000000     0.000000     0.000000        0.000000
# 25%          0.000000     0.000000     0.000000        0.000000
# 50%          1.000000     0.000000     0.000000        0.000000
# 75%          2.000000     0.000000     0.000000        0.000000
# max         33.000000    13.000000     5.000000        1.000000

# %%
#heatmap of correlations
fig, ax = plt.subplots(figsize=(11,11))   
sns.heatmap(df.corr(),annot=True, ax=ax)
# Out:
# <AxesSubplot:>

# %%
#Train Test Split
X = pd.get_dummies(df.drop("credit.policy",axis=1),drop_first=True)
y = df["credit.policy"]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
#Fit model to decision tree classifier
model = DecisionTreeClassifier()
model.fit(X_train,y_train)
base_pred = model.predict(X_test)

# %%
#Create and plot the confusion matrix
confusion_matrix(y_test,base_pred)
# Out:
# array([[ 537,   17],
#        [  15, 2305]], dtype=int64)

# %%
#Plot the normalized confusion matrix
plot_confusion_matrix(model,X_test,y_test, normalize="true")

# %%
#Display a pruned tree (entire tree is massive)
pruned_tree = DecisionTreeClassifier(max_depth = 3)
pruned_tree.fit(X_train,y_train)

plt.figure(figsize=(12,8),dpi=150)
plot_tree(pruned_tree,filled=True,feature_names=X.columns);

# %%
base_pred
#real values are y_test
# Out:
# array([1, 1, 1, ..., 1, 1, 0], dtype=int64)

# %%
#Show classification report data
print(classification_report(y_test,base_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       554
#            1       0.99      0.99      0.99      2320
#
#     accuracy                           0.99      2874
#    macro avg       0.98      0.98      0.98      2874
# weighted avg       0.99      0.99      0.99      2874

# %%
#Calculate the loss functions based on the test predictions and the real values 
MSE = mean_squared_error(y_test, base_pred)
RMSE = np.sqrt(MSE)

# %%
RMSE
# Out:
# 0.105519228509533
