# %%
#Similiar to advertising with degree of 2 instead of 1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error

#os.chdir('C:\\Users\Matthew...')
path = os.getcwd()

df = pd.read_csv("iris.csv")

# %%
#df.info()
df['species'].value_counts() 
#There are three things, no longer logistic (0 or 1), now multi-class logistic regression
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
df.head(200)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.countplot(x=df['species'], data =df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sns.scatterplot(x='sepal_length',y='sepal_width',data=df,hue='species')
#confusing because has areas with overlap, therefore we cannot use just sepal length and width
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x='petal_length',y='petal_width',data=df,hue='species')
#By using petal width and length, we get a more accurate scatterplot
#But we still have some overlap, therefore we need a combination of attributes
# Out:
# <AxesSubplot:xlabel='petal_length', ylabel='petal_width'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>
